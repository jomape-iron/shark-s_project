# %%
import pandas as pd
from datetime import date
import calendar

# %% [markdown]
# - Case Number: dafined by the date, there are too many dates with error, specifyen the month as 00, or the day as 00
# - Date: date of the attack.
# - Year: I create this column to create a line plot to my hipothesis (year by year, there are more attacks because sharks are improving them attack skills.
# - Type: type of accident, only 8 types
# - Country: more than 212
# - Area: State
# - Location: City
# - Activity: Activy while the attack
# - Name: name of the person
# - Sex: gender of thje person
# - Species: Specie of shark
# - Investigator:
# - pdf: pdf whit info (date + name)

# %%
df = pd.read_csv("Data/attacks1.csv",encoding='latin') #Load the file

# %%
df.shape #Knowing the shape of the data frame
# Out:
# (25723, 24)

# %%
df.dropna(subset=['Date'], inplace=True) #remove rows with missing (NaN) values

# %%
df.drop_duplicates(keep=False) #remove any duplicate rows in the dataframe
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# ...

# %%
unique_counts = df.nunique()
print(unique_counts) #Count unique values in each column.
# Out:
# Case Number               6285
# Date                      5433
# Year                       249
# Type                         8
# Country                    212
# Area                       825
# Location                  4108
# Activity                  1532
# Name                      5230
# Sex                          6
# Age                        157
# Injury                    3737
# Fatal (Y/N)                  8
# Time                       366
# Species                   1549
# Investigator or Source    4969
# pdf                       6291
# href formula              6290
# href                      6285
# Case Number.1             6285
# Case Number.2             6286
# original order            6301
# Unnamed: 22                  1
# Unnamed: 23                  2
# dtype: int64

# %%
for i in df.columns:
    print(i) # know all the columns that we have
# Out:
# Case Number
# Date
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Injury
# Fatal (Y/N)
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %%
df.dtypes #get the data types of all the columns
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
df.info() # get a concise summary of the information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6302 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6301 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
null_counts = df.isnull().sum()
null_counts #count all nulls
# Out:
# Case Number                  1
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
for i in df["Date"].unique():
    print(i) #print all unique values of a column
# Out:
# 25-Jun-2018
# 18-Jun-2018
# 09-Jun-2018
# 08-Jun-2018
# 04-Jun-2018
# 03-Jun-2018
# 27-May-2018
# 26-May-2018
# 24-May-2018
# 21-May-2018
# 13-May-2018
# May 2018
# 12-May-2018
# 09-May-2018
# Reported 30-Apr-2018
# 28-Apr-2018
# 25-Apr-2018
# 24-Apr-2018
# 23-Apr-2018
# 22-Apr-2018
# 19-Apr-2018
# 15-Apr-2018
# 14-Apr-2018
# Reported 10-Apr-2018
# 09-Apr-2018
# 05-Apr-2018
# 03-Apr-2018
# 31-Mar-2018
# 14-Mar-2018
# 9-Mar-2018
# 24-Feb-2018
# 23-Feb-2018
# 18-Feb-2018
# 15-Feb-2018
# 14-Feb-2018
# 11-Feb-2018
# 03-Feb-2018
# 01-Feb-2018
# 28-Jan-2018
# 21-Jan-2018
# 14-Jan-2018
# 13-Jan-2018
# 12-Jan-2018
# 05-Jan-2018
# 31-Dec-2017
# 30-Dec-2017
# 21-Dec-2017
# 09-Dec-2017
# 30-Nov-2017
# Reported 25-Nov-2017
# 24-Nov-2017
# 18-Nov-2017
# Reported 13-Nov-2017
# 13-Nov-2017
# 04-Nov-2017
# Reported 31-Oct-2017
# 28-Oct-2017
# 26-Oct-2017
# 23-Oct-2017
# 22-Oct-2017
# 21-Oct-2017
# 18-Oct-2017
# 09-Oct-2017
# 05-Oct-2017
# 01-Oct-2017
# 25-Sep-2017
# 24-Sep-2017
# 20-Sep-2017
# ...

# %%
filtered_dates = df[df['Date'].str.contains(r'\d{2}-\w{3}-\d{4}')]
print(filtered_dates)
# Out:
#      Case Number                                               Date    Year
# 0     2018.06.25                                        25-Jun-2018  2018.0  \
# 1     2018.06.18                                        18-Jun-2018  2018.0
# 2     2018.06.09                                        09-Jun-2018  2018.0
# 3     2018.06.08                                        08-Jun-2018  2018.0
# 4     2018.06.04                                        04-Jun-2018  2018.0
# ...          ...                                                ...     ...
# 6205     ND-0115                                 Before 08-Jun-1912     0.0
# 6245     ND.0060                                Before  19-Jun-1959     0.0
# 6288     ND.0014                                 Before 17-Jul-1916     0.0
# 6289     ND.0013  No date (3 days after preceding incident) & pr...     0.0
# 6290     ND.0012                                 Before 19-Jul-1913     0.0
#
#             Type       Country             Area
# ...
