# %%
import pandas as pd
from datetime import date
import calendar
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# It's better using case number than date, case number has 8702 non null vs. date 6302 non null.

# %%
df_date = pd.read_csv("Data/attacks1.csv",encoding='latin')

# %%
# Drop rows with missing values in column 'date'
df_date.dropna(subset=['Case Number'], inplace=True)
df_date
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df_date.dropna(subset=['Case Number'], inplace=True)
df_date
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Filter out rows with invalid dates
df_date = df_date[df_date['Case Number'].str.match(r'\d+-\w+\(\d{4}|\d|\.\d\)')]

# Extract dates with format "dd-Mon-yyyy" using regex pattern and combine into a single datetime column
df_date['Extracted_Dates'] = pd.to_datetime(df_date['Date'].str.extract(r'(\d+)-(\w{3})-(\d{4})').apply(lambda x: ' '.join(x) if not x.isna().any() else None, axis=1))

# Drop rows with missing values in the 'Extracted_Dates' column
df_date.dropna(subset=['Extracted_Dates'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[10], line 5
#       2 df_date = df_date[df_date['Case Number'].str.match(r'\d+-\w+\(\d{4}|\d|\.\d\)')]
#       4 # Extract dates with format "dd-Mon-yyyy" using regex pattern and combine into a single datetime column
# ----> 5 df_date['Extracted_Dates'] = pd.to_datetime(df_date['Date'].str.extract(r'(\d+)-(\w{3})-(\d{4})').apply(lambda x: ' '.join(x) if not x.isna().any() else None, axis=1))
#       7 # Drop rows with missing values in the 'Extracted_Dates' column
#       8 df_date.dropna(subset=['Extracted_Dates'], inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# ...

# %%
# Out:
#   Cell In[13], line 1
#     "1580-01-10" = "1580.01.10"
#     ^
# SyntaxError: cannot assign to literal
